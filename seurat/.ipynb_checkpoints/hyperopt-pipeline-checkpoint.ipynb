# %% [markdown]
# # Clustering 3k PBMCs following a Seurat Tutorial

# %% [markdown]
# This started out (July 2017) with a demonstration that Scanpy would allow to reproduce most of Seurat's ([Satija *et al.*, 2015](https://doi.org/10.1038/nbt.3192)) clustering tutorial ([link](http://satijalab.org/seurat/pbmc3k_tutorial.html)), which we gratefully acknowledge. In the meanwhile, we have added and removed several pieces.
#
# The data consists in *3k PBMCs from a Healthy Donor* and is freely available from 10x Genomics ([here](http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz) from this [webpage](https://support.10xgenomics.com/single-cell-gene-expression/datasets/1.1.0/pbmc3k)).

# %%
import numpy as np
import pandas as pd
import scanpy.api as sc
from scipy import sparse, io
from collections import Counter
import os.path
from sklearn.metrics.cluster import adjusted_rand_score
import matplotlib.pyplot as plt
import pickle
import os
import datetime
import hyperopt
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import time
# import utils
import seurat_utils
import hyperopt_utils
plt.ion()
plt.show()
sc.settings.set_figure_params(dpi=80)
sc.settings.verbosity = 0  # verbosity: errors (0), warnings (1), info (2), hints (3)
# sc.logging.print_versions()

# %%
# %load_ext autoreload
import importlib
importlib.reload(seurat_utils)
importlib.reload(hyperopt_utils)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# scanpy==1.3.3 anndata==0.6.13 numpy==1.14.2 scipy==1.0.0 pandas==0.22.0 scikit-learn==0.19.1 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1
# <module 'hyperopt_utils' from '/home/mada/ml/single-cell-sota/seurat/hyperopt_utils.py'>

# %% [markdown]
# ## Generic method for running bayesian hyperparm optimisation for all datasets

# %%
def runSeurat(filename, space, max_evals = 2):
    # Define function to optimise
    def evaluateSeurat(args):
        args['cluster_n_neighbors'] = int(args['cluster_n_neighbors'])
        args['cluster_n_pcs'] = int(args['cluster_n_pcs'])

        if args['bpreprocess_min_genes'] == False:
            args['preprocess_min_genes'] = -1
        if args['bpreprocess_min_cells'] == False:
            args['preprocess_min_cells'] = -1
        if args['bpreprocess_teta_total_features'] == False:
            args['preprocess_teta_total_features'] = -1
        if args['bpreprocess_filter_min_mean'] == False:
            args['preprocess_filter_min_mean'] = -1
        if args['bpreprocess_filter_min_disp'] == False:
            args['preprocess_filter_min_disp'] = -1

        if args['preprocess_teta_total_features'] is not None:
            args['preprocess_teta_total_features'] = int(args['preprocess_teta_total_features'])
        try:
            resultDict = seurat_utils.run(args)
        except:
            return { 'status' : hyperopt.STATUS_FAIL}

        print(f'>> Result: {resultDict["randIndex"]}')
        ret = {
            'loss' : -resultDict['randIndex']
            ,'status' : STATUS_OK
            ,'eval_time' : time.time()        
        }
        return ret

    trials = hyperopt_utils.getTrials(filename ,restart = False )
    evals_per_epoch = 10
    for e in range(len(trials), max_evals, evals_per_epoch):
        best = fmin(evaluateSeurat
                    ,space
                    ,algo=tpe.suggest 
                    ,max_evals= e + evals_per_epoch
                    ,trials=trials)
        print('Index ', e)
        pickle.dump(trials, open(filename, 'wb'))
    return trials

# %% [markdown]
# # BrainCIDR
#
# Run it once with all default parameters to get the parameter range

# %%
params = {}
params['load_inputDataset'] = 'brainCIDR'
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = 8000
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']='total_counts'
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = True

params['evaluate_plot_results'] = True
seurat_utils.run(params)
# Out:
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 2854 genes that are detected in less than 3 cells
# Filtering Counter({False: 13027, True: 6204})
# Keeping 6204 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:12.57)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.89) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5341774376930473
# {'cluster_n_neighbors': 10,
#  'cluster_n_pcs': 40,
#  'cluster_plot_pca': True,
#  'evaluate_plot_results': True,
#  'load_inputDataset': 'brainCIDR',
#  'preprocess_filter_max_mean': 3,
#  'preprocess_filter_min_disp': 0.5,
#  'preprocess_filter_min_mean': 0.0125,
#  'preprocess_min_cells': 3,
#  'preprocess_min_genes': 200,
#  'preprocess_normalize_per_cell': True,
#  'preprocess_regress_out': 'total_counts',
#  'preprocess_scale': 10,
#  'preprocess_teta_total_features': 8000,
#  'randIndex': 0.5341774376930473}

# %% [markdown]
# ### Hyperopt input

# %%
space = {
    'load_inputDataset' : 'brainCIDR'
    ,'bpreprocess_min_genes' : hp.choice('bpreprocess_min_genes', [True,False])
    ,'preprocess_min_genes' : hp.quniform('preprocess_min_genes', 100, 500, 10)
    
    ,'bpreprocess_min_cells' : hp.choice('bpreprocess_min_cells', [True,False])
    ,'preprocess_min_cells' : hp.quniform('preprocess_min_cells', 1, 20, 1)
    
    ,'bpreprocess_teta_total_features' : hp.choice('bpreprocess_teta_total_features', [True,False])
    ,'preprocess_teta_total_features' : hp.quniform('preprocess_teta_total_features', 5000, 15000, 1000)

    ,'preprocess_normalize_per_cell' : hp.choice('l_preprocess_normalize_per_cell', 
                                                 [True, False])

    ,'bpreprocess_filter_min_mean' : hp.choice('bpreprocess_filter_min_mean', [True,False])
    ,'preprocess_filter_min_mean' : hp.uniform('preprocess_filter_min_mean', 0, 0.2) # 0.0125
    ,'preprocess_filter_max_mean' : hp.uniform('preprocess_filter_max_mean', 0, 5)
    
    ,'bpreprocess_filter_min_disp' : hp.choice('bpreprocess_filter_min_disp', [True,False])
    ,'preprocess_filter_min_disp' : hp.uniform('preprocess_filter_min_disp', 0, 1)# 0.5
    
    ,'preprocess_regress_out' : hp.choice('l_preprocess_regress_out', ['none', 'total_counts'])
    ,'preprocess_scale' : hp.choice('l_preprocess_scale', [-1, 5, 10, 15, 20]) #10
    ,'cluster_n_neighbors' : hp.quniform('cluster_n_neighbors', 1, 20,1) #10
    ,'cluster_n_pcs' : hp.quniform('cluster_n_pcs', 20, 50, 1)  # 40
    ,'cluster_plot_pca' : False
    ,'preprocess_plot_preprocessing' : False
    ,'evaluate_plot_results': False
    ,'preprocess_verbosity' : 0
}

filename = 'brainCIDR_trials.pkl'
# Out:
# 'brainCIDR_trials.pkl'

# %%
trials=hyperopt_utils.getTrials(filename ,restart = False )
# Out:
# Reload trials size :80

# %%
trials = runSeurat(filename, space, max_evals = 200);
# Out:
# Creating new trials...
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:15.40)
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.08) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.57) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.4313024719946615
# >> Result: 0.4313024719946615
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5755 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:33.38)
# computing neighbors
#     using 'X_pca' with n_pcs = 22
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.16) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7748755069134103
# >> Result: 0.7748755069134103
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5755 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:34.83)
# computing neighbors
#     using 'X_pca' with n_pcs = 28
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.03) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5517589105910556
# >> Result: 0.5517589105910556
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 22
#     finished (0:00:00.09) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.72) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 13 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.4314718069648278
# >> Result: 0.4314718069648278
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6722 genes that are detected in less than 11.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 38
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.03) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 11 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5374968018094384
# >> Result: 0.5374968018094384
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:08.71)
# computing neighbors
#     using 'X_pca' with n_pcs = 31
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.99) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6701833428479362
# >> Result: 0.6701833428479362
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7388 genes that are detected in less than 14.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:02.03)
# computing neighbors
#     using 'X_pca' with n_pcs = 47
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.92) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5707998013372642
# >> Result: 0.5707998013372642
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6433 genes that are detected in less than 10.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:32.30)
# computing neighbors
#     using 'X_pca' with n_pcs = 44
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.84) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7215649406515465
# >> Result: 0.7215649406515465
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 29
#     finished (0:00:00.12) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.96) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5555510847664802
# >> Result: 0.5555510847664802
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:1000: RuntimeWarning: invalid value encountered in true_divide
#   X /= scale
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:788: RuntimeWarning: invalid value encountered in greater
#   if max_value is not None: X[X > max_value] = max_value
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 2854 genes that are detected in less than 3.0 cells
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:38.96)
# computing neighbors
#     using 'X_pca' with n_pcs = 24
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.87) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 11 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6683707253061745
# >> Result: 0.6683707253061745
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7792 genes that are detected in less than 16.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:29.53)
# computing neighbors
#     using 'X_pca' with n_pcs = 24
#     finished (0:00:00.11) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.76) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5069251756355734
# >> Result: 0.5069251756355734
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 2854 genes that are detected in less than 3.0 cells
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.43)
# computing neighbors
#     using 'X_pca' with n_pcs = 42
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.05) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.03) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.4348108411063758
# >> Result: 0.4348108411063758
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 49
#     finished (0:00:00.11) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.94) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6604682924332945
# >> Result: 0.6604682924332945
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.25) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5360207812909384
# >> Result: 0.5360207812909384
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:17.32)
# computing neighbors
#     using 'X_pca' with n_pcs = 22
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.08) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5860357625271305
# >> Result: 0.5860357625271305
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 45
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.09) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5284539675777276
# >> Result: 0.5284539675777276
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6962 genes that are detected in less than 12.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:31.72)
# computing neighbors
#     using 'X_pca' with n_pcs = 35
#     finished (0:00:00.06) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/neighbors/umap/umap_.py:864: RuntimeWarning: divide by zero encountered in true_divide
#   D = scipy.sparse.spdiags(1.0 / np.sqrt(diag_data), 0, graph.shape[0],
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5755 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:32.76)
# computing neighbors
#     using 'X_pca' with n_pcs = 48
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.02) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6946062684491263
# >> Result: 0.6946062684491263
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6962 genes that are detected in less than 12.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:31.85)
# computing neighbors
#     using 'X_pca' with n_pcs = 26
#     finished (0:00:00.08) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.58) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5902476499992784
# >> Result: 0.5902476499992784
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6433 genes that are detected in less than 10.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:32.58)
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.91) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6887330836737655
# >> Result: 0.6887330836737655
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5334 genes that are detected in less than 7.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:34.49)
# computing neighbors
#     using 'X_pca' with n_pcs = 45
#     finished (0:00:00.06) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.26) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 68 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.13567889332531435
# >> Result: 0.13567889332531435
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 4314 genes that are detected in less than 5.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:35.98)
# computing neighbors
#     using 'X_pca' with n_pcs = 38
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.06) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7637764191341521
# >> Result: 0.7637764191341521
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 4314 genes that are detected in less than 5.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:36.20)
# computing neighbors
#     using 'X_pca' with n_pcs = 32
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.07) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7641533237022137
# >> Result: 0.7641533237022137
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 4314 genes that are detected in less than 5.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:36.29)
# computing neighbors
#     using 'X_pca' with n_pcs = 33
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.13) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7741588164034259
# >> Result: 0.7741588164034259
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 1807 genes that are detected in less than 2.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:41.73)
# computing neighbors
#     using 'X_pca' with n_pcs = 33
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.07) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7666971128442512
# >> Result: 0.7666971128442512
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5334 genes that are detected in less than 7.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:33.32)
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.00) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6389053704609434
# >> Result: 0.6389053704609434
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5755 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:33.67)
# computing neighbors
#     using 'X_pca' with n_pcs = 25
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.90) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7259479884490602
# >> Result: 0.7259479884490602
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 3625 genes that are detected in less than 4.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 22
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.02) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5727861273567454
# >> Result: 0.5727861273567454
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6962 genes that are detected in less than 12.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:31.83)
# computing neighbors
#     using 'X_pca' with n_pcs = 33
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.99) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7995111647524837
# >> Result: 0.7995111647524837
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7192 genes that are detected in less than 13.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:30.55)
# computing neighbors
#     using 'X_pca' with n_pcs = 28
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.01) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8010444277101059
# >> Result: 0.8010444277101059
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7192 genes that are detected in less than 13.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:31.58)
# computing neighbors
#     using 'X_pca' with n_pcs = 28
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.04) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8010444277101059
# >> Result: 0.8010444277101059
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7192 genes that are detected in less than 13.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 28
#     finished (0:00:00.10) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.67) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 13 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5289211482040564
# >> Result: 0.5289211482040564
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7388 genes that are detected in less than 14.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:29.42)
# computing neighbors
#     using 'X_pca' with n_pcs = 29
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.90) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6424201746062039
# >> Result: 0.6424201746062039
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8187 genes that are detected in less than 18.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:17.33)
# computing neighbors
#     using 'X_pca' with n_pcs = 36
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.98) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5662834045190219
# >> Result: 0.5662834045190219
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7388 genes that are detected in less than 14.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 31
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.93) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6118953584827636
# >> Result: 0.6118953584827636
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6722 genes that are detected in less than 11.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:30.57)
# computing neighbors
#     using 'X_pca' with n_pcs = 27
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.02) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8281324582168761
# >> Result: 0.8281324582168761
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6433 genes that are detected in less than 10.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:08.58)
# computing neighbors
#     using 'X_pca' with n_pcs = 24
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.04) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5778701434918215
# >> Result: 0.5778701434918215
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6107 genes that are detected in less than 9.0 cells
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:1000: RuntimeWarning: invalid value encountered in true_divide
#   X /= scale
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:788: RuntimeWarning: invalid value encountered in greater
#   if max_value is not None: X[X > max_value] = max_value
# computing neighbors
#     using 'X_pca' with n_pcs = 26
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.88) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5158472157452478
# >> Result: 0.5158472157452478
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7792 genes that are detected in less than 16.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:04.75)
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.92) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5840468240789581
# >> Result: 0.5840468240789581
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6107 genes that are detected in less than 9.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 26
#     finished (0:00:00.07) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.39) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 22 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.3249622356359959
# >> Result: 0.3249622356359959
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:27.00)
# computing neighbors
#     using 'X_pca' with n_pcs = 37
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.96) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6463074399756041
# >> Result: 0.6463074399756041
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7192 genes that are detected in less than 13.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:30.37)
# computing neighbors
#     using 'X_pca' with n_pcs = 41
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.87) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5640004085804488
# >> Result: 0.5640004085804488
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7993 genes that are detected in less than 17.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:05.71)
# computing neighbors
#     using 'X_pca' with n_pcs = 34
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.05) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6875153336509526
# >> Result: 0.6875153336509526
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 31
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.10) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.4994255220396088
# >> Result: 0.4994255220396088
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8343 genes that are detected in less than 19.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:27.30)
# computing neighbors
#     using 'X_pca' with n_pcs = 29
#     finished (0:00:00.11) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.72) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5186809098240259
# >> Result: 0.5186809098240259
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7792 genes that are detected in less than 16.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.46)
# computing neighbors
#     using 'X_pca' with n_pcs = 27
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.91) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.66222815700465
# >> Result: 0.66222815700465
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 24
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.03) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 10 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5259680039542918
# >> Result: 0.5259680039542918
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8495 genes that are detected in less than 20.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:29.16)
# computing neighbors
#     using 'X_pca' with n_pcs = 39
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.26) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8092471430108296
# >> Result: 0.8092471430108296
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8343 genes that are detected in less than 19.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.40)
# computing neighbors
#     using 'X_pca' with n_pcs = 46
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.32) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.10) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8023386705777248
# >> Result: 0.8023386705777248
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:06.27)
# computing neighbors
#     using 'X_pca' with n_pcs = 39
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.30) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.45871780674689144
# >> Result: 0.45871780674689144
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8187 genes that are detected in less than 18.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:27.87)
# computing neighbors
#     using 'X_pca' with n_pcs = 43
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.05) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7069332858943357
# >> Result: 0.7069332858943357
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 4879 genes that are detected in less than 6.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 36
#     finished (0:00:00.11) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.65) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 16 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.3962588917786772
# >> Result: 0.3962588917786772
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 1807 genes that are detected in less than 2.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:44.92)
# computing neighbors
#     using 'X_pca' with n_pcs = 41
#     finished (0:00:00.23) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.73) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7933924261624802
# >> Result: 0.7933924261624802
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 3625 genes that are detected in less than 4.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:09.03)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.13) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5927219680298792
# >> Result: 0.5927219680298792
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8495 genes that are detected in less than 20.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 37
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.99) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.04) --> found 12 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.558864023216393
# >> Result: 0.558864023216393
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7792 genes that are detected in less than 16.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:36.51)
# computing neighbors
#     using 'X_pca' with n_pcs = 48
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.69) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.03) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7838517205247724
# >> Result: 0.7838517205247724
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8343 genes that are detected in less than 19.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.21)
# computing neighbors
#     using 'X_pca' with n_pcs = 45
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.57) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7954722176991684
# >> Result: 0.7954722176991684
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8343 genes that are detected in less than 19.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.29)
# computing neighbors
#     using 'X_pca' with n_pcs = 46
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.08) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8017362450276769
# >> Result: 0.8017362450276769
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7993 genes that are detected in less than 17.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.36)
# computing neighbors
#     using 'X_pca' with n_pcs = 39
#     finished (0:00:00.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.10) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.08) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6910440012600714
# >> Result: 0.6910440012600714
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8187 genes that are detected in less than 18.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:28.81)
# computing neighbors
#     using 'X_pca' with n_pcs = 46
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.01) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6906022376903161
# >> Result: 0.6906022376903161
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8495 genes that are detected in less than 20.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:27.66)
# computing neighbors
#     using 'X_pca' with n_pcs = 41
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.66) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8075038515274738
# >> Result: 0.8075038515274738
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8495 genes that are detected in less than 20.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:29.89)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.19) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.99) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8012389684018058
# >> Result: 0.8012389684018058
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7993 genes that are detected in less than 17.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:30.00)
# computing neighbors
#     using 'X_pca' with n_pcs = 42
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.70) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.6886214427207328
# >> Result: 0.6886214427207328
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 8495 genes that are detected in less than 20.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:29.76)
# computing neighbors
#     using 'X_pca' with n_pcs = 34
#     finished (0:00:00.16) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.54) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.10) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7984450532619163
# >> Result: 0.7984450532619163
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7388 genes that are detected in less than 14.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:32.51)
# computing neighbors
#     using 'X_pca' with n_pcs = 44
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.23) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 8 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7067351009408209
# >> Result: 0.7067351009408209
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 7792 genes that are detected in less than 16.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:30.32)
# computing neighbors
#     using 'X_pca' with n_pcs = 38
#     finished (0:00:00.18) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:02.50) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.08) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7620039846343958
# >> Result: 0.7620039846343958
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6962 genes that are detected in less than 12.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:36.22)
# computing neighbors
#     using 'X_pca' with n_pcs = 41
#     finished (0:00:00.17) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.47) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.02) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8169376578206262
# >> Result: 0.8169376578206262
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6962 genes that are detected in less than 12.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6433 genes that are detected in less than 10.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 6722 genes that are detected in less than 11.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 44
#     finished (0:00:00.15) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.43) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.10) --> found 7 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7784340288633455
# >> Result: 0.7784340288633455
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 4879 genes that are detected in less than 6.0 cells

# %%
df = hyperopt_utils.getResultsAsDf(trials, space)
df.head()
# Out:
#   load_inputDataset bpreprocess_min_genes  preprocess_min_genes  \
# 0         brainCIDR                 False                 430.0
# 1         brainCIDR                  True                 140.0
# 2         brainCIDR                 False                 420.0
# 3         brainCIDR                 False                 240.0
# 4         brainCIDR                 False                 250.0
#
#   bpreprocess_min_cells  preprocess_min_cells bpreprocess_teta_total_features  \
# 0                 False                   3.0                           False
# 1                 False                   3.0                            True
# 2                  True                   8.0                           False
# 3                  True                   8.0                            True
# 4                 False                  15.0                           False
#
#    preprocess_teta_total_features preprocess_normalize_per_cell  \
# 0                         11000.0                         False
# 1                         14000.0                          True
# 2                         14000.0                         False
# 3                         14000.0                         False
# 4                         13000.0                         False
#
#   bpreprocess_filter_min_mean  preprocess_filter_min_mean    ...     \
# 0                       False                    0.193999    ...
# 1                        True                    0.032831    ...
# 2                       False                    0.100963    ...
# 3                       False                    0.035382    ...
# 4                        True                    0.197635    ...
#
#    preprocess_filter_min_disp preprocess_regress_out  preprocess_scale  \
# 0                    0.225866           total_counts                20
# 1                    0.328177           total_counts                20
# 2                    0.087037           total_counts                15
# 3                    0.754317           total_counts                20
# 4                    0.737586                   none                15
#
#   cluster_n_neighbors cluster_n_pcs  cluster_plot_pca  \
# 0                12.0          40.0             False
# 1                 5.0          30.0             False
# 2                19.0          22.0             False
# 3                17.0          28.0             False
# 4                 5.0          22.0             False
#
#    preprocess_plot_preprocessing evaluate_plot_results preprocess_verbosity  \
# 0                          False                 False                    0
# 1                          False                 False                    0
# 2                          False                 False                    0
# 3                          False                 False                    0
# 4                          False                 False                    0
#
#      result
# 0       NaN
# 1 -0.431302
# 2 -0.774876
# 3 -0.551759
# 4 -0.431472
#
# [5 rows x 22 columns]

# %% [markdown]
# Best result:

# %%
df.sort_values(by='result').head()
# Out:
#    load_inputDataset bpreprocess_min_genes  preprocess_min_genes  \
# 41         brainCIDR                 False                 330.0
# 75         brainCIDR                  True                 180.0
# 55         brainCIDR                  True                 270.0
# 69         brainCIDR                  True                 260.0
# 56         brainCIDR                  True                 200.0
#
#    bpreprocess_min_cells  preprocess_min_cells  \
# 41                  True                  11.0
# 75                  True                  12.0
# 55                  True                  20.0
# 69                  True                  20.0
# 56                  True                  19.0
#
#    bpreprocess_teta_total_features  preprocess_teta_total_features  \
# 41                           False                          8000.0
# 75                           False                         12000.0
# 55                           False                          9000.0
# 69                           False                         10000.0
# 56                           False                         10000.0
#
#    preprocess_normalize_per_cell bpreprocess_filter_min_mean  \
# 41                         False                       False
# 75                          True                       False
# 55                          True                       False
# 69                          True                       False
# 56                          True                       False
#
#     preprocess_filter_min_mean    ...     preprocess_filter_min_disp  \
# 41                    0.123971    ...                       0.455819
# 75                    0.167542    ...                       0.377576
# 55                    0.170655    ...                       0.506361
# 69                    0.141818    ...                       0.460189
# 56                    0.191858    ...                       0.349847
#
#    preprocess_regress_out  preprocess_scale cluster_n_neighbors cluster_n_pcs  \
# 41           total_counts                10                16.0          27.0
# 75           total_counts                 5                16.0          41.0
# 55           total_counts                20                17.0          39.0
# 69           total_counts                20                17.0          41.0
# 56           total_counts                20                17.0          46.0
#
#     cluster_plot_pca  preprocess_plot_preprocessing evaluate_plot_results  \
# 41             False                          False                 False
# 75             False                          False                 False
# 55             False                          False                 False
# 69             False                          False                 False
# 56             False                          False                 False
#
#    preprocess_verbosity    result
# 41                    0 -0.828132
# 75                    0 -0.816938
# 55                    0 -0.809247
# 69                    0 -0.807504
# 56                    0 -0.802339
#
# [5 rows x 22 columns]

# %%
df.to_pickle('brainCIDR.pkl')

# %% [markdown]
# # PancreaticIsletCIDR
#
# Run it once with all default parameters to get the parameter range

# %%
params = {}
params['load_inputDataset'] = 'pancreaticIsletCIDR'
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = -1
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']='total_counts'
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = True

params['evaluate_plot_results'] = True
seurat_utils.run(params);
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3 cells
# Filtering Counter({False: 82947, True: 34702})
# Keeping 34702 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:05.89)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.01) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8272327964860908

# %% [markdown]
# ### Hyperopt input

# %%
space = {
    'load_inputDataset' : 'pancreaticIsletCIDR'
    ,'bpreprocess_min_genes' : hp.choice('bpreprocess_min_genes', [True,False])
    ,'preprocess_min_genes' : hp.quniform('preprocess_min_genes', 100, 500, 10)
    
    ,'bpreprocess_min_cells' : hp.choice('bpreprocess_min_cells', [True,False])
    ,'preprocess_min_cells' : hp.quniform('preprocess_min_cells', 1, 20, 1)
    
    ,'bpreprocess_teta_total_features' : hp.choice('bpreprocess_teta_total_features', [True,False])
    ,'preprocess_teta_total_features' : hp.quniform('preprocess_teta_total_features', 45000, 60000, 2000)

    ,'preprocess_normalize_per_cell' : hp.choice('l_preprocess_normalize_per_cell', 
                                                 [True, False])

    ,'bpreprocess_filter_min_mean' : hp.choice('bpreprocess_filter_min_mean', [True,False])
    ,'preprocess_filter_min_mean' : hp.uniform('preprocess_filter_min_mean', 0, 0.2) # 0.0125
    ,'preprocess_filter_max_mean' : hp.uniform('preprocess_filter_max_mean', 0, 5)
    
    ,'bpreprocess_filter_min_disp' : hp.choice('bpreprocess_filter_min_disp', [True,False])
    ,'preprocess_filter_min_disp' : hp.uniform('preprocess_filter_min_disp', 0, 1)# 0.5
    
    ,'preprocess_regress_out' : hp.choice('l_preprocess_regress_out', ['none', 'total_counts'])
    ,'preprocess_scale' : hp.choice('l_preprocess_scale', [-1, 5, 10, 15, 20]) #10
    ,'cluster_n_neighbors' : hp.quniform('cluster_n_neighbors', 1, 20,1) #10
    ,'cluster_n_pcs' : hp.quniform('cluster_n_pcs', 20, 50, 1)  # 40
    ,'cluster_plot_pca' : False
    ,'preprocess_plot_preprocessing' : False
    ,'evaluate_plot_results': False
    ,'preprocess_verbosity' : 0
}

filename = 'pancreaticIsletCIDR_trials.pkl'

# %%
# trials=hyperopt_utils.getTrials(filename ,restart = False )
# Out:
# Reload trials size :20

# %%
trials = runSeurat(filename, space, max_evals = 200);
# Out:
# Creating new trials...
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 103850 genes that are detected in less than 11.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:11.51)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.07) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.13) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7253788400416434
# >> Result: 0.7253788400416434
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:43.20)
# computing neighbors
#     using 'X_pca' with n_pcs = 29
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.11) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8178298948878161
# >> Result: 0.8178298948878161
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:1000: RuntimeWarning: invalid value encountered in true_divide
#   X /= scale
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:788: RuntimeWarning: invalid value encountered in greater
#   if max_value is not None: X[X > max_value] = max_value
# computing neighbors
#     using 'X_pca' with n_pcs = 37
#     finished (0:00:00.05) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.58) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7535354435526543
# >> Result: 0.7535354435526543
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:17.28)
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7697050169143208
# >> Result: 0.7697050169143208
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 24
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.13) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.23942498422655661
# >> Result: 0.23942498422655661
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 23
#     finished (0:00:00.04) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.65) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.24446151876040467
# >> Result: 0.24446151876040467
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 120037 genes that are detected in less than 16.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 27
#     finished (0:00:00.01) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.14) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 6 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.7697050169143208
# >> Result: 0.7697050169143208
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3.0 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 47
#     finished (0:00:00.06) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.16) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.051379462443619184
# >> Result: 0.051379462443619184
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 86874 genes that are detected in less than 7.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# computing neighbors
#     using 'X_pca' with n_pcs = 37
#     finished (0:00:00.01) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.17) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.781689396342108
# >> Result: 0.781689396342108
# Index  0
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 91467 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use

# %%
df = hyperopt_utils.getResultsAsDf(trials, space)
df.head()

# %% [markdown]
# Best result:

# %%
df['result'].min()

# %%
df.to_pickle('pancreaticIsletCIDR.pkl')

# %% [markdown]
# # Deng
#
# Run it once with all default parameters to get the parameter range

# %%
params = {}
params['load_inputDataset'] = 'deng'
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = -1
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']=None
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
seurat_utils.run(params)
# Out:
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 2854 genes that are detected in less than 3 cells
# Filtering Counter({False: 13027, True: 6204})
# Keeping 6204 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:12.57)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.13) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.89) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 9 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5341774376930473
# {'cluster_n_neighbors': 10,
#  'cluster_n_pcs': 40,
#  'cluster_plot_pca': True,
#  'evaluate_plot_results': True,
#  'load_inputDataset': 'brainCIDR',
#  'preprocess_filter_max_mean': 3,
#  'preprocess_filter_min_disp': 0.5,
#  'preprocess_filter_min_mean': 0.0125,
#  'preprocess_min_cells': 3,
#  'preprocess_min_genes': 200,
#  'preprocess_normalize_per_cell': True,
#  'preprocess_regress_out': 'total_counts',
#  'preprocess_scale': 10,
#  'preprocess_teta_total_features': 8000,
#  'randIndex': 0.5341774376930473}

# %% [markdown]
# ### Hyperopt input

# %%
space = {
    'load_inputDataset' : 'pancreaticIsletCIDR'
    ,'bpreprocess_min_genes' : hp.choice('bpreprocess_min_genes', [True,False])
    ,'preprocess_min_genes' : hp.quniform('preprocess_min_genes', 100, 500, 10)
    
    ,'bpreprocess_min_cells' : hp.choice('bpreprocess_min_cells', [True,False])
    ,'preprocess_min_cells' : hp.quniform('preprocess_min_cells', 1, 20, 1)
    
    ,'bpreprocess_teta_total_features' : hp.choice('bpreprocess_teta_total_features', [True,False])
    ,'preprocess_teta_total_features' : hp.quniform('preprocess_teta_total_features', 10000, 15000, 500)

    ,'preprocess_normalize_per_cell' : hp.choice('l_preprocess_normalize_per_cell', 
                                                 [True, False])

    ,'bpreprocess_filter_min_mean' : hp.choice('bpreprocess_filter_min_mean', [True,False])
    ,'preprocess_filter_min_mean' : hp.uniform('preprocess_filter_min_mean', 0, 0.2) # 0.0125
    ,'preprocess_filter_max_mean' : hp.uniform('preprocess_filter_max_mean', 0, 5)
    
    ,'bpreprocess_filter_min_disp' : hp.choice('bpreprocess_filter_min_disp', [True,False])
    ,'preprocess_filter_min_disp' : hp.uniform('preprocess_filter_min_disp', 0, 1)# 0.5
    
    ,'preprocess_regress_out' : hp.choice('l_preprocess_regress_out', ['none', 'total_counts'])
    ,'preprocess_scale' : hp.choice('l_preprocess_scale', [-1, 5, 10, 15, 20]) #10
    ,'cluster_n_neighbors' : hp.quniform('cluster_n_neighbors', 1, 20,1) #10
    ,'cluster_n_pcs' : hp.quniform('cluster_n_pcs', 20, 50, 1)  # 40
    ,'cluster_plot_pca' : False
    ,'preprocess_plot_preprocessing' : False
    ,'evaluate_plot_results': False
    ,'preprocess_verbosity' : 0
}

filename = 'deng_trials.pkl'

# %%
# trials=hyperopt_utils.getTrials(filename ,restart = False )
# Out:
# Reload trials size :20

# %%
trials = runSeurat(filename, space, max_evals = 500);
# Out:
# Creating new trials...
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
# /home/mada/anaconda3/lib/python3.6/site-packages/statsmodels/genmod/families/family.py:176: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:15.40)
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.08) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.57) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.01) --> found 14 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.4313024719946615
# >> Result: 0.4313024719946615
# ... reading from cache file ./cache/input-brainCIDR-matrix.h5ad
# Loading dataset brainCIDR with 22085 genes and 420 cells
# filtered out 5755 genes that are detected in less than 8.0 cells
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:33.38)

# %%
df = hyperopt_utils.getResultsAsDf(trials, space)
df.head()

# %% [markdown]
# Best result:

# %%
df['result'].min()

# %%
df.to_pickle('deng.pkl')
