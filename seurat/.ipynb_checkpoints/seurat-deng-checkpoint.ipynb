# %% [markdown]
# # Clustering 3k PBMCs following a Seurat Tutorial

# %% [markdown]
# This started out (July 2017) with a demonstration that Scanpy would allow to reproduce most of Seurat's ([Satija *et al.*, 2015](https://doi.org/10.1038/nbt.3192)) clustering tutorial ([link](http://satijalab.org/seurat/pbmc3k_tutorial.html)), which we gratefully acknowledge. In the meanwhile, we have added and removed several pieces.
#
# The data consists in *3k PBMCs from a Healthy Donor* and is freely available from 10x Genomics ([here](http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz) from this [webpage](https://support.10xgenomics.com/single-cell-gene-expression/datasets/1.1.0/pbmc3k)).

# %%
import numpy as np
import pandas as pd
import scanpy.api as sc
from scipy import sparse, io
from collections import Counter
import os.path
from sklearn.metrics.cluster import adjusted_rand_score
import matplotlib.pyplot as plt

# import utils
import seurat_utils
plt.ion()
plt.show()
sc.settings.set_figure_params(dpi=80)
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
results_file = '../write/pbmc3k.h5ad'
# Out:
# scanpy==1.3.3 anndata==0.6.13 numpy==1.14.2 scipy==1.0.0 pandas==0.22.0 scikit-learn==0.19.1 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %%
# %load_ext autoreload
import importlib
importlib.reload(seurat_utils)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# scanpy==1.3.3 anndata==0.6.13 numpy==1.14.2 scipy==1.0.0 pandas==0.22.0 scikit-learn==0.19.1 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1
# <module 'seurat_utils' from '/home/mada/ml/single-cell-sota/seurat/seurat_utils.py'>

# %% [markdown]
# # Input datasets

# %%
inputDatasets = ['pancreaticIsletCIDR']
results = []

# %% [markdown]
# ## No total counts filter/ regression

# %%
params = {}
params['load_inputDataset'] = 'pancreaticIsletCIDR'
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = None
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']=None
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3 cells
# Filtering Counter({False: 83339, True: 34310})
# Keeping 34310 genes
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:03.14) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:01.14) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 5 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.9713270358108314

# %% [markdown]
# ## No gene filtering based on dispertion

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = 50000
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = None
params['preprocess_filter_max_mean']=None
params['preprocess_filter_min_disp']=None
params['preprocess_regress_out']=None
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3 cells
# No dispertion gene filter
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:1000: RuntimeWarning: invalid value encountered in true_divide
#   X /= scale
# /home/mada/anaconda3/lib/python3.6/site-packages/scanpy/preprocessing/simple.py:788: RuntimeWarning: invalid value encountered in greater
#   if max_value is not None: X[X > max_value] = max_value
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.05) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.13) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8272327964860908

# %% [markdown]
# ## No scale

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = 50000
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']='total_counts'
params['preprocess_scale']=None

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3 cells
# Filtering Counter({False: 82947, True: 34702})
# Keeping 34702 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:02.42)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.05) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8272327964860908

# %%
results.append(resultDict)

# %% [markdown]
# ## No min genes/cells filter

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = None
params['preprocess_min_cells'] = None
# Define on the dataset
params['preprocess_teta_total_features'] = None
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] =None
params['preprocess_filter_max_mean']=None
params['preprocess_filter_min_disp']=None
params['preprocess_regress_out']=None
params['preprocess_scale']=None

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# No dispertion gene filter
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 2 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.3139706170840363

# %%
results.append(resultDict)

# %% [markdown]
# ## No preprocessing

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = None
params['preprocess_min_cells'] = None
# Define on the dataset
params['preprocess_teta_total_features'] = None
params['preprocess_normalize_per_cell'] = False
params['preprocess_filter_min_mean'] =None
params['preprocess_filter_max_mean']=None
params['preprocess_filter_min_disp']=None
params['preprocess_regress_out']=None
params['preprocess_scale']=None

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# No dispertion gene filter
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.16) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.16031081203704148

# %%
results.append(resultDict)

# %% [markdown]
# ## Normalization only, less clusters

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = None
params['preprocess_min_cells'] = None
# Define on the dataset
params['preprocess_teta_total_features'] = None
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] =None
params['preprocess_filter_max_mean']=None
params['preprocess_filter_min_disp']=None
params['preprocess_regress_out']=None
params['preprocess_scale']=None

params['cluster_n_neighbors'] = 8
params['cluster_n_pcs'] = 30
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# No dispertion gene filter
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00.00) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.11) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.5393700608696047

# %% [markdown]
# ## Normalization only, more clusters

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = None
params['preprocess_min_cells'] = None
# Define on the dataset
params['preprocess_teta_total_features'] = None
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] =None
params['preprocess_filter_max_mean']=None
params['preprocess_filter_min_disp']=None
params['preprocess_regress_out']=None
params['preprocess_scale']=None

params['cluster_n_neighbors'] = 15
params['cluster_n_pcs'] = 50
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# No dispertion gene filter
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished (0:00:00.01) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.19) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.40853956926819307

# %% [markdown]
# ## Filter less cells

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 2
# Define on the dataset
params['preprocess_teta_total_features'] = 50000
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.01
params['preprocess_filter_max_mean']=4
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']='total_counts'
params['preprocess_scale']=15

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 53630 genes that are detected in less than 2 cells
# Filtering Counter({False: 88399, True: 38224})
# Keeping 38224 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:08.74)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.06) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8272327964860908

# %%
params = {}
params['load_inputDataset'] = inputDatasets[0]
params['preprocess_min_genes'] = 200
params['preprocess_min_cells'] = 3
# Define on the dataset
params['preprocess_teta_total_features'] = 50000
params['preprocess_normalize_per_cell'] = True
params['preprocess_filter_min_mean'] = 0.0125
params['preprocess_filter_max_mean']=3
params['preprocess_filter_min_disp']=0.5
params['preprocess_regress_out']='total_counts'
params['preprocess_scale']=10

params['cluster_n_neighbors'] = 10
params['cluster_n_pcs'] = 40
params['cluster_plot_pca'] = False

params['evaluate_plot_results'] = True
resultDict = seurat_utils.run(params)
results.append(resultDict)
# Out:
# ... reading from cache file ./cache/input-pancreaticIsletCIDR-matrix.h5ad
# Loading dataset pancreaticIsletCIDR with 180253 genes and 60 cells
# filtered out 62604 genes that are detected in less than 3 cells
# Filtering Counter({False: 82947, True: 34702})
# Keeping 34702 genes
# regressing out ['total_counts']
#     sparse input is densified and may lead to high memory use
#     finished (0:01:00.80)
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished (0:00:00.05) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     finished (0:00:00.12) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished (0:00:00.00) --> found 4 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical)
# Rand_index 0.8272327964860908

# %% [markdown]
# ## Render all combinations

# %%
pd.DataFrame( results)
# Out:
#    cluster_n_neighbors  cluster_n_pcs  cluster_plot_pca  \
# 0                   10             40             False
# 1                   10             40             False
# 2                   10             40             False
# 3                   10             40             False
# 4                   10             40             False
# 5                    8             30             False
# 6                   15             50             False
# 7                   10             40             False
# 8                   10             40             False
#
#    evaluate_plot_results    load_inputDataset  preprocess_filter_max_mean  \
# 0                   True  pancreaticIsletCIDR                         3.0
# 1                   True  pancreaticIsletCIDR                         NaN
# 2                   True  pancreaticIsletCIDR                         3.0
# 3                   True  pancreaticIsletCIDR                         NaN
# 4                   True  pancreaticIsletCIDR                         NaN
# 5                   True  pancreaticIsletCIDR                         NaN
# 6                   True  pancreaticIsletCIDR                         NaN
# 7                   True  pancreaticIsletCIDR                         4.0
# 8                   True  pancreaticIsletCIDR                         3.0
#
#    preprocess_filter_min_disp  preprocess_filter_min_mean  \
# 0                         0.5                      0.0125
# 1                         NaN                         NaN
# 2                         0.5                      0.0125
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         0.5                      0.0100
# 8                         0.5                      0.0125
#
#    preprocess_min_cells  preprocess_min_genes  preprocess_normalize_per_cell  \
# 0                   3.0                 200.0                           True
# 1                   3.0                 200.0                           True
# 2                   3.0                 200.0                           True
# 3                   NaN                   NaN                           True
# 4                   NaN                   NaN                          False
# 5                   NaN                   NaN                           True
# 6                   NaN                   NaN                           True
# 7                   2.0                 200.0                           True
# 8                   3.0                 200.0                           True
#
#   preprocess_regress_out  preprocess_scale  preprocess_teta_total_features  \
# 0                   None              10.0                             NaN
# 1                   None              10.0                         50000.0
# 2           total_counts               NaN                         50000.0
# 3                   None               NaN                             NaN
# 4                   None               NaN                             NaN
# 5                   None               NaN                             NaN
# 6                   None               NaN                             NaN
# 7           total_counts              15.0                         50000.0
# 8           total_counts              10.0                         50000.0
#
#    randIndex
# 0   0.971327
# 1   0.827233
# 2   0.827233
# 3   0.313971
# 4   0.160311
# 5   0.539370
# 6   0.408540
# 7   0.827233
# 8   0.827233
