# %%
import sys
sys.path.append("..") # this adds to path parent directory in order to import utils file
sys.path.append("../gmm/")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import umap
import random
from tqdm import tqdm
import numpy as np
import scipy


import utils
# Out:
# elbowAnalysis
# silhouetteAnalyis

# %%
# %load_ext autoreload
import importlib
importlib.reload(utils)
# Out:
# elbowAnalysis
# silhouetteAnalyis
# <module 'utils' from '../utils.py'>

# %%
# dataset = 'brainCIDR'
# df, truth = gmm_utils.loadData(dataset)

# %%
def getStatisticsForDataset(df, name, truth = None):
    def addStatistics(s, statistics, name = '#_cells_per_gene', reference = None):
        statistics[f'Average {name}'] = s.mean()
        if reference is not None:
            statistics[f'Percentual average {name}'] = 100 * s.mean()/reference
        statistics[f'Std {name}'] = s.std()
        statistics[f'Kurtosis {name}'] = s.kurtosis()
        statistics[f'Skew {name}'] = s.skew()
        statistics[f'Median {name}'] = s.median()
        return statistics
    
    ## Calculate statistics
    statistics = {}
    statistics['name'] = name
    statistics['Total number of cells'] = df.shape[0]
    statistics['Total number of genes'] = df.shape[1]
    statistics['Percentage of 0 values'] = 100 * Counter(np.ravel(df.values))[0]/len(np.ravel(df.values))
    statistics['Max dataset value'] = df.max().max()
    
    discreteDf = np.zeros(df.shape)
    discreteDf[np.where(df>0)] = 1
    nbCellsPerGene=pd.Series(discreteDf.sum(axis =0 ))
    statistics = addStatistics(nbCellsPerGene, statistics, name = 'number of cells per gene', reference=df.shape[0])
    nbGenesPerCells=pd.Series(discreteDf.sum(axis =1))
    statistics = addStatistics(nbGenesPerCells, statistics, name = 'number of genes per cell', reference=df.shape[1])
    
    ## Truth related statistics
    if truth is not None:
        statistics['Number of clusters']=len(truth['clusters'].unique())
        statistics['Expected cluster size base on expected #clusters'] = df.shape[0]//len(truth['clusters'].unique())
        clusterSizes = truth['clusters'].value_counts().values
#         statistics['max_cluster_size'] = clusterSizes[0]
#         statistics['min_cluster_size'] = clusterSizes[-1]
    
    return statistics

# %%
cols = [
    'name',
    'Total number of cells',
    'Total number of genes',
    'Max dataset value',
    'Percentage of 0 values',
    'Number of clusters',
    'Expected cluster size base on expected #clusters',
    
    'Average number of genes per cell',
    'Percentual average number of genes per cell',
    'Std number of genes per cell',
    'Kurtosis number of genes per cell',
    'Skew number of genes per cell',
    'Median number of genes per cell',
    
    
    'Average number of cells per gene',
    'Percentual average number of cells per gene',
    'Std number of cells per gene',
    'Kurtosis number of cells per gene',
    'Skew number of cells per gene',
    'Median number of cells per gene'
]

# %%
r = pd.DataFrame(columns=cols) 
datasets = ['brainCIDR', 'pancreaticIsletCIDR', 'deng', 'sce10x_qc', 'sce2_qc', 'sce8_qc','celegans']
for dataset in datasets:
    df, truth = utils.loadData(dataset)
    s = getStatisticsForDataset(df, dataset, truth)
    r = r.append(s, ignore_index=True)

# %% [markdown]
# # Plot distributions

# %%
    ## Generate plots
    plt.figure(figsize=(14,5))
    plt.subplot(121)
    plt.title(f'Logscale sum of counts per genes for {name}')
    df.sum(axis=0).hist(bins = 100, log = True)

    plt.subplot(122)
    plt.title(f'Logscale sum of counts per cells for {name}')
    df.sum(axis=1).hist(bins = 100, log = True)

# %%
r.set_index('name', inplace=True, drop = True)
r = r.T
r = r.applymap("{:,.0f}".format)

# %%
r
# Out:
# name                                             brainCIDR  \
# Total number of cells                                  420
# Total number of genes                               22,085
# Max dataset value                                   58,272
# Percentage of 0 values                                  81
# Number of clusters                                       8
# Expected cluster size base on expected #clusters        52
# Average number of genes per cell                     4,107
# Percentual average number of genes per cell             19
# Std number of genes per cell                         1,686
# Kurtosis number of genes per cell                        5
# Skew number of genes per cell                            1
# Median number of genes per cell                      3,868
# Average number of cells per gene                        78
# Percentual average number of cells per gene             19
# Std number of cells per gene                            90
# Kurtosis number of cells per gene                        1
# Skew number of cells per gene                            1
# Median number of cells per gene                         41
#
# name                                             pancreaticIsletCIDR     deng  \
# Total number of cells                                             60      268
# Total number of genes                                        180,253   22,431
# Max dataset value                                          1,429,282  693,974
# Percentage of 0 values                                            78       60
# Number of clusters                                                 6       10
# Expected cluster size base on expected #clusters                  10       26
# Average number of genes per cell                              39,970    8,907
# Percentual average number of genes per cell                       22       40
# Std number of genes per cell                                  12,621    1,725
# Kurtosis number of genes per cell                                  0        2
# Skew number of genes per cell                                     -1        1
# Median number of genes per cell                               40,910    8,613
# Average number of cells per gene                                  13      106
# Percentual average number of cells per gene                       22       40
# Std number of cells per gene                                      15      100
# Kurtosis number of cells per gene                                  1       -1
# Skew number of cells per gene                                      1        0
# Median number of cells per gene                                    7       66
#
# name                                             sce10x_qc sce2_qc sce8_qc  \
# Total number of cells                                  902     340     296
# Total number of genes                               16,468  14,804  15,571
# Max dataset value                                    8,556   2,946   2,495
# Percentage of 0 values                                  45      52      56
# Number of clusters                                       3       8       8
# Expected cluster size base on expected #clusters       300      42      37
# Average number of genes per cell                     9,054   7,095   6,775
# Percentual average number of genes per cell             55      48      44
# Std number of genes per cell                           773   1,854   2,143
# Kurtosis number of genes per cell                       -0      -1      -1
# Skew number of genes per cell                           -0       0      -0
# Median number of genes per cell                      9,073   7,033   6,802
# Average number of cells per gene                       496     163     129
# Percentual average number of cells per gene             55      48      44
# Std number of cells per gene                           304     104      88
# Kurtosis number of cells per gene                       -1      -1      -1
# Skew number of cells per gene                           -0       0       0
# Median number of cells per gene                        502     156     118
#
# name                                             celegans
# Total number of cells                               7,603
# Total number of genes                              12,355
# Max dataset value                                     219
# Percentage of 0 values                                 99
# Number of clusters                                    nan
# Expected cluster size base on expected #clusters      nan
# Average number of genes per cell                      175
# Percentual average number of genes per cell             1
# Std number of genes per cell                          121
# Kurtosis number of genes per cell                      30
# Skew number of genes per cell                           4
# Median number of genes per cell                       138
# Average number of cells per gene                      107
# Percentual average number of cells per gene             1
# Std number of cells per gene                          278
# Kurtosis number of cells per gene                      71
# Skew number of cells per gene                           7
# Median number of cells per gene                        24

# %%
r[['celegans']].dropna()
# Out:
# name                                             celegans
# Total number of cells                               7,603
# Total number of genes                              12,355
# Max dataset value                                     219
# Percentage of 0 values                                 99
# Number of clusters                                    nan
# Expected cluster size base on expected #clusters      nan
# Average number of genes per cell                      175
# Percentual average number of genes per cell             1
# Std number of genes per cell                          121
# Kurtosis number of genes per cell                      30
# Skew number of genes per cell                           4
# Median number of genes per cell                       138
# Average number of cells per gene                      107
# Percentual average number of cells per gene             1
# Std number of cells per gene                          278
# Kurtosis number of cells per gene                      71
# Skew number of cells per gene                           7
# Median number of cells per gene                        24
